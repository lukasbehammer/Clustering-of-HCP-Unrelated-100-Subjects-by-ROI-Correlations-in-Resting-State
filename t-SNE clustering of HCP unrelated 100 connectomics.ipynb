# %% [markdown]
# ## Import and Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Visualize Timeseries

# %%
timeseries = np.load("./Data/mean_intensity_per_region.npy")

plt.plot(timeseries[:,:2])

# %% [markdown]
# ## Compute Pearson`s r
