# %% [markdown]
# ## Import and Setup

# %%
from Main import get_timeseries_per_patient, get_all_timeseries, timeseries_pearson_corr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get all timeseries

# %%
temp = get_timeseries_per_patient(patient="001")
# get_all_timeseries()

# %% [markdown]
# ## Visualize Timeseries

# %%
timeseries = np.load("./Data/mean_intensity_per_region.npy")

plt.plot(timeseries[:, :2]);

# %% [markdown]
# ## Compute Pearson`s r

# %%
Rs = timeseries_pearson_corr(timeseries, step_width=5, overlap_percentage=0.2)

# %%
sns.heatmap(Rs[50], cmap='Spectral');
